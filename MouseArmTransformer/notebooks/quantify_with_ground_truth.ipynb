# %%
import glob
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import pickle
import sys

# From arm
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.optim as optim
from scipy.signal import savgol_filter
from scipy.spatial.distance import euclidean
from sklearn.linear_model import Lasso, LassoCV, LinearRegression, Ridge, RidgeCV
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from tqdm import tqdm

from lifting_transformer.lifting_transformer import (
    criterion,
    data,
    helper,
    inference,
    model,
    training,
)
from mausspaun.data_processing.dlc import (
    DLC_TO_MUJOCO_MAPPING,
    MUJOCO_TO_DLC_MAPPING,
    align_data_with_rig_markers,
)
from mausspaun.visualization.gui import app
from mausspaun.visualization.plot_3D_video import plot_3d_video, plot_split_3d_video

plt.style.use('cyhsm')

# %load_ext autoreload
# %autoreload 2

# %%
mouse_name = 'HoneyBee'
day = 77
attempt = 1
part = 0
base_path = '/data/mausspaun/'

# %%
# Test inference
(X_3d_test, X_2d_c1_test, X_2d_c2_test, cam_positions, likelihood_c1, likelihood_c2) = helper.load_single_session()
cam_positions_dict = {key: X_2d_c1_test[:, i, :] for i, key in enumerate(helper.mausspaun_keys)}
inference_preds = inference.run_inference(cam_positions_dict)
# Out:
# Shape of /data/markus/mausspaun/calibration/data/2018_mouse_reaching_rig5/calibration/CAL_front16.jpg is (280, 432), while at leat one previous image was of shape (300, 448).
# Ignoring the mismatch and keeping the larger image: (300, 448).
# [94, 10, 12, 76, 53, 73, 73, 63, 80, 52]
# [152163, 432, 5]
# MuJoCo session created
# MuJoCO session closed...
# Procrustes alignment error: 0.008391390369790641
# Nan Values in 3D:  0
# Nan Values in 2D Camera 1:  0
# Nan Values in 2D Camera 2:  0
# Total 3D (32, 4611, 3), Remaining 3D points (4611, 32, 3), 2D Camera 1 (4611, 32, 2), 2D Camera 2 (4611, 32, 2)
# (4611, 32, 2)
# Inference loss: 1.88097

# %%
avg_error, errors = inference.evaluate_ground_truth(inference_preds, mouse_name, day, attempt, verbose=2)
# Out:
# MuJoCo session created
# MuJoCO session closed...
# Procrustes alignment error: 0.008391397293761028
#
# Overall Average Error: 0.20299792646953782
# Average Error Per Marker:
#  marker
# joystick              0.133685
# left_elbow           -1.000000
# left_finger0          0.180174
# left_finger1          0.214403
# left_finger2          0.224748
# left_finger3          0.419620
# left_hand             0.164300
# left_wrist            0.190739
# lick                  0.256951
# nose                  2.249819
# right_elbow           0.130046
# right_finger0_0       0.201809
# right_finger0_1       0.203767
# right_finger0_2       0.183565
# right_finger0_3       0.177192
# right_finger1_0       0.185978
# right_finger1_1       0.184377
# right_finger1_2       0.189802
# right_finger1_3       0.184116
# right_finger2_0       0.158768
# right_finger2_1       0.146140
# right_finger2_2       0.125897
# right_finger2_3       0.132081
# right_finger3_0       0.175006
# right_finger3_1       0.125727
# right_finger3_2       0.112460
# right_finger3_3       0.125498
# right_hand            0.174502
# right_shoulder        0.161000
# right_wrist           0.128151
# right_wrist_bottom    0.101759
# right_wrist_top       0.189480
# watertube             0.167373
# Name: error, dtype: float64
#
# Max Error Per Marker:
#  marker
# joystick              0.139729
# left_elbow           -1.000000
# left_finger0          0.293701
# left_finger1          0.297517
# left_finger2          0.328090
# left_finger3          0.525775
# left_hand             0.300617
# left_wrist            0.247888
# lick                  0.282092
# nose                  2.260796
# right_elbow           0.149321
# right_finger0_0       0.221283
# right_finger0_1       0.229606
# right_finger0_2       0.191493
# right_finger0_3       0.181761
# right_finger1_0       0.208144
# right_finger1_1       0.204504
# right_finger1_2       0.223087
# right_finger1_3       0.202908
# right_finger2_0       0.173680
# right_finger2_1       0.146192
# right_finger2_2       0.129529
# right_finger2_3       0.134982
# right_finger3_0       0.186192
# right_finger3_1       0.129065
# right_finger3_2       0.116995
# right_finger3_3       0.132955
# right_hand            0.199489
# right_shoulder        0.189067
# right_wrist           0.150606
# right_wrist_bottom    0.111759
# right_wrist_top       0.216086
# watertube             0.190761
# Name: error, dtype: float64
#
# Min Error Per Marker:
#  marker
# joystick              0.127641
# left_elbow           -1.000000
# left_finger0          0.066647
# left_finger1          0.131289
# left_finger2          0.121406
# left_finger3          0.313465
# left_hand             0.027983
# left_wrist            0.133590
# lick                  0.231811
# nose                  2.238841
# right_elbow           0.110770
# right_finger0_0       0.182336
# right_finger0_1       0.177928
# right_finger0_2       0.175636
# right_finger0_3       0.172622
# right_finger1_0       0.163813
# right_finger1_1       0.164249
# right_finger1_2       0.156517
# right_finger1_3       0.165323
# right_finger2_0       0.143855
# right_finger2_1       0.146089
# right_finger2_2       0.122264
# right_finger2_3       0.129180
# right_finger3_0       0.163821
# right_finger3_1       0.122389
# right_finger3_2       0.107924
# right_finger3_3       0.118041
# right_hand            0.149516
# right_shoulder        0.132933
# right_wrist           0.105696
# right_wrist_bottom    0.091760
# right_wrist_top       0.162873
# watertube             0.143986
# Name: error, dtype: float64
#
# Standard Deviation Per Marker:
#  marker
# joystick              0.008548
# left_elbow            0.000000
# left_finger0          0.160551
# left_finger1          0.117541
# left_finger2          0.146148
# left_finger3          0.150125
# left_hand             0.192781
# left_wrist            0.080821
# lick                  0.035554
# nose                  0.015524
# right_elbow           0.027260
# right_finger0_0       0.027540
# right_finger0_1       0.036542
# right_finger0_2       0.011213
# right_finger0_3       0.006462
# right_finger1_0       0.031347
# right_finger1_1       0.028464
# right_finger1_2       0.047072
# right_finger1_3       0.026577
# right_finger2_0       0.021089
# right_finger2_1       0.000073
# right_finger2_2       0.005137
# right_finger2_3       0.004102
# right_finger3_0       0.015819
# right_finger3_1       0.004721
# right_finger3_2       0.006415
# right_finger3_3       0.010546
# right_hand            0.035336
# right_shoulder        0.039692
# right_wrist           0.031756
# right_wrist_bottom    0.014142
# right_wrist_top       0.037627
# watertube             0.033075
# Name: error, dtype: float64

# %% [markdown]
# ---
# # Test triangulated 3D without using the transformer

# %%
# Original triangulated:
filepaths = app.generate_filepaths(base_path + 'videos/videos_dlc2/', mouse_name, day, attempt, part)
X_3d_train, X_2d_c1_train, X_2d_c2_train, cam_positions, likelihood_c1, likelihood_c2 = helper.get_training_data(
    filepaths[0][1], filepaths[1][1], likelihood_cutoff=0, convert_to_mujoco=False)
X_3d_train_dict = {key: X_3d_train[:, i, :] for i, key in enumerate(helper.mausspaun_keys)}
X_3d_train_mujoco, (dlc_c, dlc_s, T, mujoco_c, mujoco_s) = helper.dlc_to_mujoco(X_3d_train_dict)
# Out:
# Shape of /data/markus/mausspaun/calibration/data/2018_mouse_reaching_rig5/calibration/CAL_front16.jpg is (280, 432), while at leat one previous image was of shape (300, 448).
# Ignoring the mismatch and keeping the larger image: (300, 448).
# [49, 45, 12, 89, 57, 18, 82, 58, 34, 65]
# [152163, 432, 5]
# Nan Values in 3D:  0
# Nan Values in 2D Camera 1:  0
# Nan Values in 2D Camera 2:  0
# Total 3D (32, 4611, 3), Remaining 3D points (4611, 32, 3), 2D Camera 1 (4611, 32, 2), 2D Camera 2 (4611, 32, 2)
# MuJoCo session created
# MuJoCO session closed...
# Procrustes alignment error: 0.008391397293761028

# %%
avg_error, errors = inference.evaluate_ground_truth(X_3d_train_mujoco, mouse_name, day, attempt, verbose=2)
# Out:
# MuJoCo session created
# MuJoCO session closed...
# Procrustes alignment error: 0.008391397293761028
#
# Overall Average Error: 0.14169749928829228
# Average Error Per Marker:
#  marker
# joystick              2.737469e-06
# left_elbow           -1.000000e+00
# left_finger0          5.921396e-02
# left_finger1          2.250235e-02
# left_finger2          4.866854e-02
# left_finger3          3.405603e-01
# left_hand             1.504562e-01
# left_wrist            1.523506e-01
# lick                  9.191131e-01
# nose                  1.917610e+00
# right_elbow           2.243991e-06
# right_finger0_0       2.196880e-06
# right_finger0_1       1.684020e-06
# right_finger0_2       8.304622e-07
# right_finger0_3       8.232992e-07
# right_finger1_0       8.818575e-07
# right_finger1_1       3.411930e-06
# right_finger1_2       1.687735e-06
# right_finger1_3       9.909085e-07
# right_finger2_0       4.579007e-07
# right_finger2_1       2.200803e-06
# right_finger2_2       2.970170e-06
# right_finger2_3       1.546481e-06
# right_finger3_0       8.387842e-07
# right_finger3_1       9.080343e-07
# right_finger3_2       2.109431e-06
# right_finger3_3       2.923337e-06
# right_hand            1.456711e-06
# right_shoulder        7.661107e-07
# right_wrist           2.561380e-06
# right_wrist_bottom    2.065502e+00
# right_wrist_top       2.249171e-06
# watertube             1.873322e-06
# Name: error, dtype: float64
#
# Max Error Per Marker:
#  marker
# joystick              3.517789e-06
# left_elbow           -1.000000e+00
# left_finger0          7.006815e-02
# left_finger1          3.238614e-02
# left_finger2          6.867629e-02
# left_finger3          4.938680e-01
# left_hand             1.653519e-01
# left_wrist            1.541275e-01
# lick                  1.771272e+00
# nose                  1.999784e+00
# right_elbow           2.986470e-06
# right_finger0_0       2.846264e-06
# right_finger0_1       2.163437e-06
# right_finger0_2       9.361403e-07
# right_finger0_3       1.620394e-06
# right_finger1_0       1.463917e-06
# right_finger1_1       3.778629e-06
# right_finger1_2       2.125022e-06
# right_finger1_3       1.517135e-06
# right_finger2_0       7.967532e-07
# right_finger2_1       2.905063e-06
# right_finger2_2       3.253442e-06
# right_finger2_3       2.035534e-06
# right_finger3_0       1.605946e-06
# right_finger3_1       1.478019e-06
# right_finger3_2       2.727675e-06
# right_finger3_3       3.715796e-06
# right_hand            2.180701e-06
# right_shoulder        1.316118e-06
# right_wrist           3.180048e-06
# right_wrist_bottom    2.260541e+00
# right_wrist_top       3.048975e-06
# watertube             3.252149e-06
# Name: error, dtype: float64
#
# Min Error Per Marker:
#  marker
# joystick              1.957149e-06
# left_elbow           -1.000000e+00
# left_finger0          4.835977e-02
# left_finger1          1.261856e-02
# left_finger2          2.866078e-02
# left_finger3          1.872526e-01
# left_hand             1.355605e-01
# left_wrist            1.505738e-01
# lick                  6.695437e-02
# nose                  1.835436e+00
# right_elbow           1.501512e-06
# right_finger0_0       1.547497e-06
# right_finger0_1       1.204603e-06
# right_finger0_2       7.247841e-07
# right_finger0_3       2.620479e-08
# right_finger1_0       2.997984e-07
# right_finger1_1       3.045231e-06
# right_finger1_2       1.250447e-06
# right_finger1_3       4.646817e-07
# right_finger2_0       1.190482e-07
# right_finger2_1       1.496543e-06
# right_finger2_2       2.686898e-06
# right_finger2_3       1.057428e-06
# right_finger3_0       7.162250e-08
# right_finger3_1       3.380497e-07
# right_finger3_2       1.491187e-06
# right_finger3_3       2.130878e-06
# right_hand            7.327213e-07
# right_shoulder        2.161037e-07
# right_wrist           1.942712e-06
# right_wrist_bottom    1.870463e+00
# right_wrist_top       1.449368e-06
# watertube             4.944944e-07
# Name: error, dtype: float64
#
# Standard Deviation Per Marker:
#  marker
# joystick              1.103539e-06
# left_elbow            0.000000e+00
# left_finger0          1.535015e-02
# left_finger1          1.397779e-02
# left_finger2          2.829524e-02
# left_finger3          2.168098e-01
# left_hand             2.106568e-02
# left_wrist            2.512807e-03
# lick                  1.205134e+00
# nose                  1.162120e-01
# right_elbow           1.050024e-06
# right_finger0_0       9.183671e-07
# right_finger0_1       6.779979e-07
# right_finger0_2       1.494514e-07
# right_finger0_3       1.127262e-06
# right_finger1_0       8.231558e-07
# right_finger1_1       5.185905e-07
# right_finger1_2       6.184183e-07
# right_finger1_3       7.441970e-07
# right_finger2_0       4.792098e-07
# right_finger2_1       9.959740e-07
# right_finger2_2       4.006068e-07
# right_finger2_3       6.916252e-07
# right_finger3_0       1.084930e-06
# right_finger3_1       8.060799e-07
# right_finger3_2       8.743290e-07
# right_finger3_3       1.120706e-06
# right_hand            1.023876e-06
# right_shoulder        7.778274e-07
# right_wrist           8.749284e-07
# right_wrist_bottom    2.758264e-01
# right_wrist_top       1.131093e-06
# watertube             1.949956e-06
# Name: error, dtype: float64

# %%
#
import numpy as np

# %%
data = np.load('/data/markus/mausspaun/GLM/data/base_thesis_27Oct2023.npy', allow_pickle=True)[()]

# %%
data["{'mouse_name': 'HoneyBee', 'day': 77, 'attempt': 1, 'scan_idx': 0}"]['mujoco_dlc_3d'].shape
# Out:
# (119518, 3, 25)

# %%
data["{'mouse_name': 'HoneyBee', 'day': 77, 'attempt': 1, 'scan_idx': 0}"]['mujoco_dlc_3d'][0:10, ...]
# Out:
# array([[[-0.88000107, -1.0248587 , -0.64307237, -0.62303734,
#          -0.64125746, -0.5589383 , -0.47154105, -0.4201652 ,
#          -0.34084615, -0.25886047, -0.48423055, -0.4093773 ,
#          -0.3051834 , -0.21574567, -0.50437903, -0.43909872,
#          -0.3592582 , -0.2813206 , -0.5722114 , -0.54590887,
#          -0.5117479 , -0.45699507,  1.5233262 , -0.27969486,
#          -0.2621609 ],
#         [-1.1758918 , -0.48632216, -1.6362121 , -1.6420741 ,
#          -1.6524564 , -1.8928018 , -1.9768685 , -2.0680866 ,
#          -1.9819282 , -2.0305784 , -2.1521223 , -2.9077263 ,
#          -1.9909034 ],
#         [-0.5957717 , -1.4743295 , -1.0087234 , -0.91258466,
#          -1.1515169 , -0.9569451 , -0.838816  , -0.8307276 ,
#          -0.8282626 , -0.8431668 , -0.92932445, -0.9374438 ,
#          -0.94051   , -0.9587981 , -1.0162266 , -1.0396084 ,
#          -1.0471002 , -1.0742205 , -1.098145  , -1.1619269 ,
#          -1.1963316 , -1.2254969 ,  0.31695506, -0.18322851,
#          -0.70898676]],
#
#        [[-0.88188577, -1.0247512 , -0.6442361 , -0.6229565 ,
#          -0.64115673, -0.55856085, -0.46917802, -0.4183704 ,
#          -0.33712438, -0.25516552, -0.4836968 , -0.40769362,
#          -0.30481282, -0.21398397, -0.502717  , -0.43757313,
#          -0.3573733 , -0.27909988, -0.5724954 , -0.5447763 ,
#          -0.508101  , -0.4573084 ,  1.5203806 , -0.2789588 ,
#          -0.26249892],
#         [-1.0980415 , -0.41707602, -1.5666554 , -1.5802776 ,
#          -1.58829   , -1.8242717 , -1.909269  , -1.9999696 ,
#          -2.0637689 , -2.1076717 , -1.962338  , -2.0708687 ,
#          -2.12646   , -2.17728   , -1.9603083 , -2.0660365 ,
#          -2.1415167 , -2.196811  , -1.8022435 , -1.8541908 ,
#          -1.9103458 , -1.9644853 , -2.1560347 , -2.908477  ,
#          -1.9190682 ],
#         [-0.58767015, -1.4569373 , -1.0016208 , -0.90631807,
#          -1.14523   , -0.95309544, -0.83649176, -0.828034  ,
#          -0.8266124 , -0.84063447, -0.92638105, -0.9351227 ,
#          -0.93817896, -0.9555185 , -1.0135441 , -1.0371009 ,
#          -1.0449693 , -1.0718349 , -1.0946823 , -1.1587498 ,
#          -1.1931659 , -1.22301   ,  0.31660524, -0.18263733,
#          -0.7114444 ]],
#
#        [[-0.8927469 , -1.0456388 , -0.6579702 , -0.63172555,
#          -0.6534721 , -0.56908023, -0.48108482, -0.42794946,
#          -0.3468683 , -0.26419902, -0.49051675, -0.41600665,
#          -0.3115817 , -0.2185783 , -0.51038206, -0.44623363,
#          -0.3637866 , -0.28589162, -0.5815448 , -0.55580944,
#          -0.51886535, -0.46906394,  1.5185026 , -0.2870866 ,
#          -0.26948398],
#         [-1.0831207 , -0.3367672 , -1.4939948 , -1.5193797 ,
#          -1.5251151 , -1.7558278 , -1.8386583 , -1.9317997 ,
#          -1.9943422 , -2.036623  , -1.8920478 , -1.9974706 ,
#          -2.056277  , -2.1054692 , -1.888008  , -1.9934763 ,
#          -2.067342  , -2.1248772 , -1.7276404 , -1.7789334 ,
#          -1.835707  , -1.8912426 , -2.1572995 , -2.9061427 ,
#          -1.845825  ],
#         [-0.57658184, -1.4512959 , -0.9906847 , -0.89674306,
#          -1.1351982 , -0.9458185 , -0.8306461 , -0.82436115,
#          -0.82277495, -0.8370247 , -0.9212808 , -0.93023294,
#          -0.9333469 , -0.9510753 , -1.0083727 , -1.0325291 ,
#          -1.040357  , -1.0676585 , -1.0865849 , -1.1529692 ,
#          -1.1873201 , -1.2174716 ,  0.31661457, -0.18014514,
#          -0.71263283]]], dtype=float32)
